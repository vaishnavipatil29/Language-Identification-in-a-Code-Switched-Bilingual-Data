# %%
import pandas as pd
df = pd.read_csv('sentence_wise_wer.csv')
df
# Out:
#                                                original  \
# 0     SSTTTTEEEEESEEEETTTSSSSTTTSSSSSTTTTTTTTTTTTTSS...
# 1     SSSSSSSTTTEEETSSTTTTTTSSSSSSSSSSTTTTTTTTTTSSST...
# 2     SSTTTTTTTTSSSTTTTTTTSSSSSSSTTTTSEEETTTTTSTTTTT...
# 3     SSTTTSEEEEEEESSSSTTTTTTTTTTTTSSSSSTTTTSSSSTTTT...
# 4     SSEEETTTTTSTTTSTTTTTTSSSSSTTTTTTTSTTTTTTTESSST...
# ...                                                 ...
# 1042                                    SSSETTTTTTTTSS
# 1043                                    SSSTTTTTTTEEES
# 1044                                    SSTTTTETETTTSS
# 1045                                     SSSEETTTTTTTS
# 1046                                      SSTTTEEETTSS
#
#                                               predicted   ix  wer  cer  \
# 0     SSTTTTSEEEEESEEEETTSSTSTTSSSTTTTTTTTTTTTTTTTTS...  431    1   20
# 1     SSSSSTTTTSTETTSTTTTTTSSSSSSSSTTTTTTTTTTTSSSTTT...  549    2   14
# 2     SSTTTTTTTTTSSTTTTTTTSTTTTSSTTTTSEEETTTTTTSTTTT...  230    1   17
# ...

# %%
org = []
# Python code to convert string to list character-wise
def Convert(string):
    list1=[]
    list1[:0]=string
    return list1

# %%
org = []
pred = []

for i in range(1047):
    l1 = Convert(df['original'][i])
    l1.remove(' ')
    l2 = Convert(df['predicted'][i])
    l2.remove(' ')
    #print(l1)
    #print(l2)
    min_len = min(len(l1),len(l2))
    l1 = l1[0:min_len]
    l2 = l2[0:min_len]
    org.append(l1)
    pred.append(l2)
    
import itertools    

    
org_val = list(itertools.chain.from_iterable(org)) 
pred_val = list(itertools.chain.from_iterable(pred))

# %%
len(org_val)
# Out:
# 35878

# %%
len(pred_val)
# Out:
# 35878

# %%
from sklearn.metrics import classification_report
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

def print_classification_report(preds, y_test):

    # classification report
    #print(classification_report(y_test, preds))
    #333333333333df = pd.DataFrame(classification_report(y_test, preds,output_dict=True)).transpose()
    fig, ax = plt.subplots(figsize=(8,8))

    # color map
    cmap='Blues'
    # cmap = sn.diverging_palette(0, 230, 90, 60, as_cmap=True)

    cm = confusion_matrix(y_test, preds, labels=list(set(y_test)))
    # display(cm)
    df_cm = pd.DataFrame(cm, list(set(y_test)), list(set(y_test)))
    # display(df_cm)
    sn.set(font_scale=1.6)
    ax = sn.heatmap(df_cm, annot=True, annot_kws={"size": 15}, fmt='.4g', ax=ax, square=True)
    
    #ax = sns.heatmap(cf_matrix/np.sum(cf_matrix), annot=True, 
     #       fmt='.2%', cmap='Blues')

    ax.set_title('Telugu Confusion Matrix \n\n');
    ax.set_xlabel('\nPredicted Values')
    ax.set_ylabel('Actual Values ');

    ## Ticket labels - List must be in alphabetical order
    ax.xaxis.set_ticklabels(list(set(y_test)))
    ax.yaxis.set_ticklabels(list(set(y_test)))

    plt.show()
    return

# %%
print_classification_report(pred_val,org_val)
# Out:
# /home/orchids/miniconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/orchids/miniconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/orchids/miniconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
print_classification_report(pred_val,org_val)
